# %% [markdown]
# <a href="https://colab.research.google.com/github/ashleybrea/05-AIT-HW/blob/main/04_DeepLearning_HW_AshleyBrea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Objectives:
# Design and implement an MLP using Keras that incorporates both residual and additional skip connections. Your model will be trained to perfectly overfit a single batch (batch size = 128) from a large dataset while performing poorly on validation data. Additionally, you will visualize your network architecture using the Netron app and include the exported diagram. The final submission must be uploaded to GitHub, and the submission text must start with the GitHub links.

# %% [markdown]
# # Dataset Prep & Processing

# %% [markdown]
# Use a large dataset such as the UCI Covertype Dataset, but you can use your own (e.g. from project work).
#
# Preprocess the data by:
#
# * Handling missing values.
#
# *   Normalizing numerical features.
# *   Encoding categorical variables.
# *   Split the dataset into training and validation sets.

# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

# fetch dataset
covertype = fetch_ucirepo(id=31)

# data (as pandas dataframes)
X = covertype.data.features
y = covertype.data.targets

# metadata
print(covertype.metadata)

# variable information
print(covertype.variables)
# Out:
# {'uci_id': 31, 'name': 'Covertype', 'repository_url': 'https://archive.ics.uci.edu/dataset/31/covertype', 'data_url': 'https://archive.ics.uci.edu/static/public/31/data.csv', 'abstract': 'Classification of pixels into 7 forest cover types based on attributes such as elevation, aspect, slope, hillshade, soil-type, and more.', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 581012, 'num_features': 54, 'feature_types': ['Categorical', 'Integer'], 'demographics': [], 'target_col': ['Cover_Type'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1998, 'last_updated': 'Sat Mar 16 2024', 'dataset_doi': '10.24432/C50K5N', 'creators': ['Jock Blackard'], 'intro_paper': None, 'additional_info': {'summary': 'Predicting forest cover type from cartographic variables only (no remotely sensed data).  The actual forest cover type for a given observation (30 x 30 meter cell) was determined from US Forest Service (USFS) Region 2 Resource Information System (RIS) data.  Independent variables were derived from data originally obtained from US Geological Survey (USGS) and USFS data.  Data is in raw form (not scaled) and contains binary (0 or 1) columns of data for qualitative independent variables (wilderness areas and soil types).\r\n\r\nThis study area includes four wilderness areas located in the Roosevelt National Forest of northern Colorado.  These areas represent forests with minimal human-caused disturbances, so that existing forest cover types are more a result of ecological processes rather than forest management practices.\r\n\r\nSome background information for these four wilderness areas: Neota (area 2) probably has the highest mean elevational value of the 4 wilderness areas. Rawah (area 1) and Comanche Peak (area 3) would have a lower mean elevational value, while Cache la Poudre (area 4) would have the lowest mean elevational value. \r\n\r\nAs for primary major tree species in these areas, Neota would have spruce/fir (type 1), while Rawah and Comanche Peak would probably have lodgepole pine (type 2) as their primary species, followed by spruce/fir and aspen (type 5). Cache la Poudre would tend to have Ponderosa pine (type 3), Douglas-fir (type 6), and cottonwood/willow (type 4).  \r\n\r\nThe Rawah and Comanche Peak areas would tend to be more typical of the overall dataset than either the Neota or Cache la Poudre, due to their assortment of tree species and range of predictive variable values (elevation, etc.)  Cache la Poudre would probably  be more unique than the others, due to its relatively low  elevation range and species composition. ', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Given is the attribute name, attribute type, the measurement unit and a brief description.  The forest cover type is the classification  problem.  The order of this listing corresponds to the order of numerals along the rows of the database.\r\n\r\nName / Data Type / Measurement / Description\r\n\r\nElevation / quantitative /meters / Elevation in meters\r\nAspect / quantitative / azimuth / Aspect in degrees azimuth\r\nSlope / quantitative / degrees / Slope in degrees\r\nHorizontal_Distance_To_Hydrology / quantitative / meters / Horz Dist to nearest surface water features\r\nVertical_Distance_To_Hydrology / quantitative / meters / Vert Dist to nearest surface water features\r\nHorizontal_Distance_To_Roadways / quantitative / meters / Horz Dist to nearest roadway\r\nHillshade_9am / quantitative / 0 to 255 index / Hillshade index at 9am, summer solstice\r\nHillshade_Noon / quantitative / 0 to 255 index / Hillshade index at noon, summer soltice\r\nHillshade_3pm / quantitative / 0 to 255 index / Hillshade index at 3pm, summer solstice\r\nHorizontal_Distance_To_Fire_Points / quantitative / meters / Horz Dist to nearest w ...
#                                   name     role     type demographic  \
# 0                            Elevation  Feature  Integer        None
# 1                               Aspect  Feature  Integer        None
# 2                                Slope  Feature  Integer        None
# 3     Horizontal_Distance_To_Hydrology  Feature  Integer        None
# 4       Vertical_Distance_To_Hydrology  Feature  Integer        None
# 5      Horizontal_Distance_To_Roadways  Feature  Integer        None
# 6                        Hillshade_9am  Feature  Integer        None
# 7                       Hillshade_Noon  Feature  Integer        None
# 8                        Hillshade_3pm  Feature  Integer        None
# 9   Horizontal_Distance_To_Fire_Points  Feature  Integer        None
# 10                    Wilderness_Area1  Feature  Integer        None
# 11                          Soil_Type1  Feature  Integer        None
# 12                          Soil_Type2  Feature  Integer        None
# 13                          Soil_Type3  Feature  Integer        None
# 14                          Soil_Type4  Feature  Integer        None
# 15                          Soil_Type5  Feature  Integer        None
# 16                          Soil_Type6  Feature  Integer        None
# 17                          Soil_Type7  Feature  Integer        None
# 18                          Soil_Type8  Feature  Integer        None
# 19                          Soil_Type9  Feature  Integer        None
# 20                         Soil_Type10  Feature  Integer        None
# 21                         Soil_Type11  Feature  Integer        None
# 22                         Soil_Type12  Feature  Integer        None
# 23                         Soil_Type13  Feature  Integer        None
# 24                         Soil_Type14  Feature  Integer        None
# 25                         Soil_Type15  Feature  Integer        None
# 26                         Soil_Type16  Feature  Integer        None
# 27                         Soil_Type17  Feature  Integer        None
# 28                         Soil_Type18  Feature  Integer        None
# 29                         Soil_Type19  Feature  Integer        None
# 30                         Soil_Type20  Feature  Integer        None
# 31                         Soil_Type21  Feature  Integer        None
# 32                         Soil_Type22  Feature  Integer        None
# 33                         Soil_Type23  Feature  Integer        None
# 34                         Soil_Type24  Feature  Integer        None
# 35                         Soil_Type25  Feature  Integer        None
# 36                         Soil_Type26  Feature  Integer        None
# 37                         Soil_Type27  Feature  Integer        None
# 38                         Soil_Type28  Feature  Integer        None
# 39                         Soil_Type29  Feature  Integer        None
# 40                         Soil_Type30  Feature  Integer        None
# 41                         Soil_Type31  Feature  Integer        None
# 42                         Soil_Type32  Feature  Integer        None
# 43                         Soil_Type33  Feature  Integer        None
# 44                         Soil_Type34  Feature  Integer        None
# 45                         Soil_Type35  Feature  Integer        None
# 46                         Soil_Type36  Feature  Integer        None
# 47                         Soil_Type37  Feature  Integer        None
# 48                         Soil_Type38  Feature  Integer        None
# 49                         Soil_Type39  Feature  Integer        None
# 50                         Soil_Type40  Feature  Integer        None
# 51                          Cover_Type   Target  Integer        None
# 52                    Wilderness_Area2  Feature  Integer        None
# 53                    Wilderness_Area3  Feature  Integer        None
# 54                    Wilderness_Area4  Feature  Integer        None
#
#    description units missing_values
# 0         None  None             no
# 1         None  None             no
# 2         None  None             no
# 3         None  None             no
# 4         None  None             no
# 5         None  None             no
# 6         None  None             no
# 7         None  None             no
# 8         None  None             no
# 9         None  None             no
# 10        None  None             no
# 11        None  None             no
# 12        None  None             no
# 13        None  None             no
# 14        None  None             no
# 15        None  None             no
# 16        None  None             no
# 17        None  None             no
# 18        None  None             no
# 19        None  None             no
# 20        None  None             no
# 21        None  None             no
# 22        None  None             no
# 23        None  None             no
# 24        None  None             no
# 25        None  None             no
# 26        None  None             no
# 27        None  None             no
# 28        None  None             no
# 29        None  None             no
# 30        None  None             no
# 31        None  None             no
# 32        None  None             no
# 33        None  None             no
# 34        None  None             no
# 35        None  None             no
# 36        None  None             no
# 37        None  None             no
# 38        None  None             no
# 39        None  None             no
# 40        None  None             no
# 41        None  None             no
# 42        None  None             no
# 43        None  None             no
# 44        None  None             no
# 45        None  None             no
# 46        None  None             no
# 47        None  None             no
# 48        None  None             no
# 49        None  None             no
# 50        None  None             no
# 51        None  None             no
# 52        None  None             no
# 53        None  None             no
# 54        None  None             no

# %%
# HANDLING MISSING VALUES - the website states that there are no missing values

# Split the dataset
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42, shuffle=True)

# Normalizing Numerical Values - only our X in this case
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Encoding Categorical Variables - our target
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
y_train["Cover_Type"] = to_categorical(y_train["Cover_Type"]-1, num_classes=7)
y_val["Cover_Type"] = to_categorical(y_val["Cover_Type"]-1, num_classes=7)

# %% [markdown]
# # Model Architecture

# %% [markdown]
# *keep the number of trainable parameters as low as possible. Define the following neural network:
#
# **Initial Layers**: Build an MLP in Keras to process the input features.
#
# **Custom Residual Block**:
#
# *   Using the Keras Functional API, create a block with at least two Dense layers with ReLU activations.
# *   Implement a residual connection by adding the block’s input to its output (apply a linear projection with an extra Dense layer if the dimensions differ).
#
# **Additional Skip Connection:**
#
# * Implement an extra skip connection that bypasses one or more intermediate layers outside the residual block.
#
# **Final Layers:**
# * Add further Dense layers.
# * Include an output layer appropriate for the task (e.g., a single unit with sigmoid activation for binary classification).*

# %%
from ast import mod
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add

from keras import layers
from keras import activations

# creating custom residual block with residual connection
# we have 54 features, e.g. inputs
inputs = Input(shape=(54,))

layer1 = Dense(7, activation='relu')(inputs)
layer2 = Dense(7, activation='relu')(layer1)
layer3 = Dense(7, activation='relu')(layer2)
layer4 = Dense(7, activation='relu')(layer3)

residual_connection = Add()([layer1, layer4])

layer5 = Dense(7, activation='relu')(residual_connection)

# additional skip connection and final layers
skip_connection = Add()([layer5, layer1])

layer6 = Dense(7, activation='relu')(skip_connection)

layer6 = Dense(7, activation='relu')(layer6)

# output layer
output = Dense(7, activation='softmax')(layer6)
model = Model(inputs=inputs, outputs=output)
model.summary()
model.save('Assmt05_ashley_brea_overfitting.h5')
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 54)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 7)              │            385 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 7)              │             56 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 7)              │             56 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 7)              │             56 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 7)              │              0 │ dense[0][0],           │
# │                           │                        │                │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 7)              │             56 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 7)              │              0 │ dense_4[0][0],         │
# │                           │                        │                │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 7)              │             56 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 7)              │             56 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 7)              │             56 │ dense_6[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 777 (3.04 KB)
#  Trainable params: 777 (3.04 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Visualization
#
#
# * Save your complete model (e.g., as a .h5 file or in JSON format).
# * Open the saved model in the Netron app (https://netron.app/) and export the network diagram as an image.
# * Ensure that the exported image clearly shows all parts of your architecture, including both residual and skip connections.

# %% [markdown]
# # Training & Evaluation
#
#
#
# **Overfitting Experiment:**
# *   Select a single batch of 128 samples from the training set.
# * Train your model exclusively on this batch until you approach 0 loss.
#
# **Validation Check:**
# * Evaluate the overfitted model on the validation set to confirm that it performs poorly, demonstrating a lack of generalization.
#
# **Conclusions:**
# * At the end of your code, print the following information:
# * Number of parameters:
# * Final training loss:
# * Final validation loss:

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 128 samples
x_sample, y_sample = X_train[:128], y_train[:128]

model_train = model.fit(x_sample, y_sample,
                        validation_data=(X_val, y_val),
                        epochs=1000,
                        batch_size=128,
                        verbose=2)
# Out:
# Epoch 1/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1016 - loss: 1.7671 - val_accuracy: 0.0965 - val_loss: 1.7409
# Epoch 2/1000
# 1/1 - 3s - 3s/step - accuracy: 0.1094 - loss: 1.7577 - val_accuracy: 0.1213 - val_loss: 1.7314
# Epoch 3/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1172 - loss: 1.7483 - val_accuracy: 0.1289 - val_loss: 1.7217
# Epoch 4/1000
# 1/1 - 3s - 3s/step - accuracy: 0.1250 - loss: 1.7388 - val_accuracy: 0.1366 - val_loss: 1.7120
# Epoch 5/1000
# 1/1 - 3s - 3s/step - accuracy: 0.1406 - loss: 1.7293 - val_accuracy: 0.1451 - val_loss: 1.7023
# Epoch 6/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1484 - loss: 1.7198 - val_accuracy: 0.1628 - val_loss: 1.6925
# Epoch 7/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1719 - loss: 1.7102 - val_accuracy: 0.1803 - val_loss: 1.6827
# Epoch 8/1000
# 1/1 - 3s - 3s/step - accuracy: 0.1797 - loss: 1.7006 - val_accuracy: 0.1896 - val_loss: 1.6729
# Epoch 9/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1797 - loss: 1.6910 - val_accuracy: 0.1977 - val_loss: 1.6630
# Epoch 10/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1875 - loss: 1.6815 - val_accuracy: 0.2041 - val_loss: 1.6532
# Epoch 11/1000
# 1/1 - 8s - 8s/step - accuracy: 0.1953 - loss: 1.6719 - val_accuracy: 0.2097 - val_loss: 1.6434
# Epoch 12/1000
# 1/1 - 2s - 2s/step - accuracy: 0.1953 - loss: 1.6624 - val_accuracy: 0.2134 - val_loss: 1.6336
# Epoch 13/1000
# 1/1 - 3s - 3s/step - accuracy: 0.1953 - loss: 1.6529 - val_accuracy: 0.2151 - val_loss: 1.6238
# Epoch 14/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1953 - loss: 1.6436 - val_accuracy: 0.2165 - val_loss: 1.6142
# Epoch 15/1000
# 1/1 - 2s - 2s/step - accuracy: 0.1797 - loss: 1.6342 - val_accuracy: 0.2183 - val_loss: 1.6046
# Epoch 16/1000
# 1/1 - 3s - 3s/step - accuracy: 0.1875 - loss: 1.6250 - val_accuracy: 0.2292 - val_loss: 1.5951
# Epoch 17/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1641 - loss: 1.6158 - val_accuracy: 0.2407 - val_loss: 1.5857
# Epoch 18/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1719 - loss: 1.6066 - val_accuracy: 0.2583 - val_loss: 1.5763
# Epoch 19/1000
# 1/1 - 5s - 5s/step - accuracy: 0.1953 - loss: 1.5975 - val_accuracy: 0.2889 - val_loss: 1.5671
# Epoch 20/1000
# 1/1 - 5s - 5s/step - accuracy: 0.2344 - loss: 1.5885 - val_accuracy: 0.3092 - val_loss: 1.5579
# Epoch 21/1000
# 1/1 - 4s - 4s/step - accuracy: 0.2578 - loss: 1.5796 - val_accuracy: 0.3186 - val_loss: 1.5489
# Epoch 22/1000
# 1/1 - 3s - 3s/step - accuracy: 0.2578 - loss: 1.5708 - val_accuracy: 0.3301 - val_loss: 1.5400
# Epoch 23/1000
# 1/1 - 5s - 5s/step - accuracy: 0.2500 - loss: 1.5621 - val_accuracy: 0.3437 - val_loss: 1.5311
# Epoch 24/1000
# 1/1 - 3s - 3s/step - accuracy: 0.2969 - loss: 1.5535 - val_accuracy: 0.3524 - val_loss: 1.5224
# Epoch 25/1000
# 1/1 - 5s - 5s/step - accuracy: 0.2969 - loss: 1.5450 - val_accuracy: 0.3620 - val_loss: 1.5139
# Epoch 26/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3047 - loss: 1.5366 - val_accuracy: 0.3649 - val_loss: 1.5054
# Epoch 27/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.5284 - val_accuracy: 0.3649 - val_loss: 1.4972
# Epoch 28/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.5203 - val_accuracy: 0.3649 - val_loss: 1.4890
# Epoch 29/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.5124 - val_accuracy: 0.3649 - val_loss: 1.4810
# Epoch 30/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.5046 - val_accuracy: 0.3649 - val_loss: 1.4731
# Epoch 31/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4969 - val_accuracy: 0.3649 - val_loss: 1.4654
# Epoch 32/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4893 - val_accuracy: 0.3649 - val_loss: 1.4578
# Epoch 33/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3125 - loss: 1.4819 - val_accuracy: 0.3649 - val_loss: 1.4504
# Epoch 34/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4745 - val_accuracy: 0.3649 - val_loss: 1.4431
# Epoch 35/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4673 - val_accuracy: 0.3649 - val_loss: 1.4360
# Epoch 36/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3125 - loss: 1.4603 - val_accuracy: 0.3649 - val_loss: 1.4290
# Epoch 37/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4533 - val_accuracy: 0.3649 - val_loss: 1.4221
# Epoch 38/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4465 - val_accuracy: 0.3649 - val_loss: 1.4154
# Epoch 39/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4398 - val_accuracy: 0.3649 - val_loss: 1.4089
# Epoch 40/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4333 - val_accuracy: 0.3649 - val_loss: 1.4025
# Epoch 41/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4269 - val_accuracy: 0.3649 - val_loss: 1.3963
# Epoch 42/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4206 - val_accuracy: 0.3649 - val_loss: 1.3902
# Epoch 43/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4144 - val_accuracy: 0.3649 - val_loss: 1.3842
# Epoch 44/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4083 - val_accuracy: 0.3649 - val_loss: 1.3785
# Epoch 45/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.4023 - val_accuracy: 0.3649 - val_loss: 1.3728
# Epoch 46/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3125 - loss: 1.3965 - val_accuracy: 0.3649 - val_loss: 1.3673
# Epoch 47/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3908 - val_accuracy: 0.3649 - val_loss: 1.3619
# Epoch 48/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3851 - val_accuracy: 0.3649 - val_loss: 1.3566
# Epoch 49/1000
# 1/1 - 4s - 4s/step - accuracy: 0.3125 - loss: 1.3796 - val_accuracy: 0.3649 - val_loss: 1.3514
# Epoch 50/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3125 - loss: 1.3740 - val_accuracy: 0.3649 - val_loss: 1.3463
# Epoch 51/1000
# 1/1 - 2s - 2s/step - accuracy: 0.3125 - loss: 1.3686 - val_accuracy: 0.3649 - val_loss: 1.3414
# Epoch 52/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3125 - loss: 1.3632 - val_accuracy: 0.3649 - val_loss: 1.3365
# Epoch 53/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3579 - val_accuracy: 0.3649 - val_loss: 1.3317
# Epoch 54/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3527 - val_accuracy: 0.3649 - val_loss: 1.3270
# Epoch 55/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3475 - val_accuracy: 0.3649 - val_loss: 1.3224
# Epoch 56/1000
# 1/1 - 4s - 4s/step - accuracy: 0.3125 - loss: 1.3424 - val_accuracy: 0.3649 - val_loss: 1.3179
# Epoch 57/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3125 - loss: 1.3373 - val_accuracy: 0.3651 - val_loss: 1.3134
# Epoch 58/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3322 - val_accuracy: 0.3672 - val_loss: 1.3091
# Epoch 59/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3125 - loss: 1.3272 - val_accuracy: 0.3747 - val_loss: 1.3048
# Epoch 60/1000
# 1/1 - 4s - 4s/step - accuracy: 0.3203 - loss: 1.3223 - val_accuracy: 0.4040 - val_loss: 1.3007
# Epoch 61/1000
# 1/1 - 3s - 3s/step - accuracy: 0.3750 - loss: 1.3173 - val_accuracy: 0.3960 - val_loss: 1.2966
# Epoch 62/1000
# 1/1 - 5s - 5s/step - accuracy: 0.3359 - loss: 1.3125 - val_accuracy: 0.4250 - val_loss: 1.2926
# Epoch 63/1000
# 1/1 - 5s - 5s/step - accuracy: 0.4219 - loss: 1.3077 - val_accuracy: 0.4608 - val_loss: 1.2887
# Epoch 64/1000
# 1/1 - 5s - 5s/step - accuracy: 0.4922 - loss: 1.3030 - val_accuracy: 0.4798 - val_loss: 1.2849
# Epoch 65/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5156 - loss: 1.2984 - val_accuracy: 0.4851 - val_loss: 1.2811
# Epoch 66/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2938 - val_accuracy: 0.4855 - val_loss: 1.2775
# Epoch 67/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2894 - val_accuracy: 0.4872 - val_loss: 1.2739
# Epoch 68/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2850 - val_accuracy: 0.4873 - val_loss: 1.2704
# Epoch 69/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2806 - val_accuracy: 0.4873 - val_loss: 1.2670
# Epoch 70/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2763 - val_accuracy: 0.4873 - val_loss: 1.2637
# Epoch 71/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2722 - val_accuracy: 0.4873 - val_loss: 1.2605
# Epoch 72/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2680 - val_accuracy: 0.4873 - val_loss: 1.2574
# Epoch 73/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2640 - val_accuracy: 0.4873 - val_loss: 1.2544
# Epoch 74/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2601 - val_accuracy: 0.4873 - val_loss: 1.2515
# Epoch 75/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5156 - loss: 1.2562 - val_accuracy: 0.4873 - val_loss: 1.2487
# Epoch 76/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2524 - val_accuracy: 0.4873 - val_loss: 1.2459
# Epoch 77/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5156 - loss: 1.2487 - val_accuracy: 0.4873 - val_loss: 1.2432
# Epoch 78/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2451 - val_accuracy: 0.4873 - val_loss: 1.2405
# Epoch 79/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2415 - val_accuracy: 0.4873 - val_loss: 1.2379
# Epoch 80/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2380 - val_accuracy: 0.4873 - val_loss: 1.2353
# Epoch 81/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2346 - val_accuracy: 0.4873 - val_loss: 1.2328
# Epoch 82/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5156 - loss: 1.2312 - val_accuracy: 0.4873 - val_loss: 1.2304
# Epoch 83/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2279 - val_accuracy: 0.4873 - val_loss: 1.2280
# Epoch 84/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2246 - val_accuracy: 0.4873 - val_loss: 1.2257
# Epoch 85/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2214 - val_accuracy: 0.4873 - val_loss: 1.2234
# Epoch 86/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2182 - val_accuracy: 0.4873 - val_loss: 1.2211
# Epoch 87/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2151 - val_accuracy: 0.4873 - val_loss: 1.2188
# Epoch 88/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2120 - val_accuracy: 0.4873 - val_loss: 1.2166
# Epoch 89/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2090 - val_accuracy: 0.4873 - val_loss: 1.2144
# Epoch 90/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2060 - val_accuracy: 0.4873 - val_loss: 1.2122
# Epoch 91/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.2031 - val_accuracy: 0.4873 - val_loss: 1.2100
# Epoch 92/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.2002 - val_accuracy: 0.4873 - val_loss: 1.2079
# Epoch 93/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1973 - val_accuracy: 0.4873 - val_loss: 1.2058
# Epoch 94/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1944 - val_accuracy: 0.4873 - val_loss: 1.2037
# Epoch 95/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1916 - val_accuracy: 0.4873 - val_loss: 1.2016
# Epoch 96/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1888 - val_accuracy: 0.4873 - val_loss: 1.1996
# Epoch 97/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5156 - loss: 1.1860 - val_accuracy: 0.4873 - val_loss: 1.1976
# Epoch 98/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5156 - loss: 1.1833 - val_accuracy: 0.4873 - val_loss: 1.1956
# Epoch 99/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1806 - val_accuracy: 0.4873 - val_loss: 1.1936
# Epoch 100/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1779 - val_accuracy: 0.4873 - val_loss: 1.1917
# Epoch 101/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1753 - val_accuracy: 0.4873 - val_loss: 1.1897
# Epoch 102/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1726 - val_accuracy: 0.4873 - val_loss: 1.1878
# Epoch 103/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1700 - val_accuracy: 0.4873 - val_loss: 1.1858
# Epoch 104/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5156 - loss: 1.1673 - val_accuracy: 0.4873 - val_loss: 1.1839
# Epoch 105/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1646 - val_accuracy: 0.4873 - val_loss: 1.1819
# Epoch 106/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1619 - val_accuracy: 0.4873 - val_loss: 1.1799
# Epoch 107/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1592 - val_accuracy: 0.4873 - val_loss: 1.1779
# Epoch 108/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1564 - val_accuracy: 0.4873 - val_loss: 1.1759
# Epoch 109/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5156 - loss: 1.1537 - val_accuracy: 0.4873 - val_loss: 1.1739
# Epoch 110/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5156 - loss: 1.1509 - val_accuracy: 0.4873 - val_loss: 1.1720
# Epoch 111/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1482 - val_accuracy: 0.4873 - val_loss: 1.1700
# Epoch 112/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1454 - val_accuracy: 0.4873 - val_loss: 1.1681
# Epoch 113/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1427 - val_accuracy: 0.4873 - val_loss: 1.1661
# Epoch 114/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1399 - val_accuracy: 0.4873 - val_loss: 1.1642
# Epoch 115/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1372 - val_accuracy: 0.4873 - val_loss: 1.1623
# Epoch 116/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1344 - val_accuracy: 0.4873 - val_loss: 1.1604
# Epoch 117/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1316 - val_accuracy: 0.4873 - val_loss: 1.1586
# Epoch 118/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1288 - val_accuracy: 0.4873 - val_loss: 1.1567
# Epoch 119/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5156 - loss: 1.1260 - val_accuracy: 0.4873 - val_loss: 1.1548
# Epoch 120/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5156 - loss: 1.1232 - val_accuracy: 0.4873 - val_loss: 1.1530
# Epoch 121/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1203 - val_accuracy: 0.4873 - val_loss: 1.1511
# Epoch 122/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1174 - val_accuracy: 0.4873 - val_loss: 1.1492
# Epoch 123/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1145 - val_accuracy: 0.4873 - val_loss: 1.1473
# Epoch 124/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.1116 - val_accuracy: 0.4873 - val_loss: 1.1454
# Epoch 125/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1086 - val_accuracy: 0.4873 - val_loss: 1.1435
# Epoch 126/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.1056 - val_accuracy: 0.4873 - val_loss: 1.1416
# Epoch 127/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5156 - loss: 1.1026 - val_accuracy: 0.4873 - val_loss: 1.1396
# Epoch 128/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.0995 - val_accuracy: 0.4873 - val_loss: 1.1376
# Epoch 129/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0963 - val_accuracy: 0.4873 - val_loss: 1.1357
# Epoch 130/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0931 - val_accuracy: 0.4873 - val_loss: 1.1337
# Epoch 131/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0898 - val_accuracy: 0.4877 - val_loss: 1.1316
# Epoch 132/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0865 - val_accuracy: 0.4885 - val_loss: 1.1295
# Epoch 133/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0831 - val_accuracy: 0.4893 - val_loss: 1.1274
# Epoch 134/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0796 - val_accuracy: 0.4901 - val_loss: 1.1253
# Epoch 135/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0760 - val_accuracy: 0.4911 - val_loss: 1.1231
# Epoch 136/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0723 - val_accuracy: 0.4917 - val_loss: 1.1210
# Epoch 137/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.0686 - val_accuracy: 0.4920 - val_loss: 1.1188
# Epoch 138/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0648 - val_accuracy: 0.4921 - val_loss: 1.1166
# Epoch 139/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0611 - val_accuracy: 0.4924 - val_loss: 1.1145
# Epoch 140/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0575 - val_accuracy: 0.4930 - val_loss: 1.1123
# Epoch 141/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5156 - loss: 1.0538 - val_accuracy: 0.4950 - val_loss: 1.1102
# Epoch 142/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5156 - loss: 1.0502 - val_accuracy: 0.4996 - val_loss: 1.1080
# Epoch 143/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5234 - loss: 1.0465 - val_accuracy: 0.5043 - val_loss: 1.1058
# Epoch 144/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5391 - loss: 1.0428 - val_accuracy: 0.5078 - val_loss: 1.1036
# Epoch 145/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5469 - loss: 1.0390 - val_accuracy: 0.5096 - val_loss: 1.1013
# Epoch 146/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5625 - loss: 1.0353 - val_accuracy: 0.5109 - val_loss: 1.0991
# Epoch 147/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5703 - loss: 1.0314 - val_accuracy: 0.5120 - val_loss: 1.0968
# Epoch 148/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5703 - loss: 1.0275 - val_accuracy: 0.5136 - val_loss: 1.0945
# Epoch 149/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5781 - loss: 1.0236 - val_accuracy: 0.5161 - val_loss: 1.0921
# Epoch 150/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5781 - loss: 1.0196 - val_accuracy: 0.5171 - val_loss: 1.0898
# Epoch 151/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5781 - loss: 1.0155 - val_accuracy: 0.5176 - val_loss: 1.0874
# Epoch 152/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5781 - loss: 1.0114 - val_accuracy: 0.5179 - val_loss: 1.0850
# Epoch 153/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 1.0072 - val_accuracy: 0.5181 - val_loss: 1.0825
# Epoch 154/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 1.0027 - val_accuracy: 0.5182 - val_loss: 1.0799
# Epoch 155/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 0.9982 - val_accuracy: 0.5183 - val_loss: 1.0771
# Epoch 156/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9936 - val_accuracy: 0.5182 - val_loss: 1.0741
# Epoch 157/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5859 - loss: 0.9887 - val_accuracy: 0.5181 - val_loss: 1.0707
# Epoch 158/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5859 - loss: 0.9835 - val_accuracy: 0.5179 - val_loss: 1.0671
# Epoch 159/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9779 - val_accuracy: 0.5178 - val_loss: 1.0633
# Epoch 160/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5859 - loss: 0.9724 - val_accuracy: 0.5175 - val_loss: 1.0596
# Epoch 161/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9672 - val_accuracy: 0.5175 - val_loss: 1.0561
# Epoch 162/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9620 - val_accuracy: 0.5173 - val_loss: 1.0526
# Epoch 163/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9570 - val_accuracy: 0.5170 - val_loss: 1.0495
# Epoch 164/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9528 - val_accuracy: 0.5164 - val_loss: 1.0467
# Epoch 165/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9487 - val_accuracy: 0.5154 - val_loss: 1.0445
# Epoch 166/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9447 - val_accuracy: 0.5144 - val_loss: 1.0426
# Epoch 167/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5859 - loss: 0.9405 - val_accuracy: 0.5131 - val_loss: 1.0411
# Epoch 168/1000
# 1/1 - 2s - 2s/step - accuracy: 0.5859 - loss: 0.9363 - val_accuracy: 0.5120 - val_loss: 1.0400
# Epoch 169/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5859 - loss: 0.9322 - val_accuracy: 0.5111 - val_loss: 1.0392
# Epoch 170/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9283 - val_accuracy: 0.5105 - val_loss: 1.0386
# Epoch 171/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9245 - val_accuracy: 0.5103 - val_loss: 1.0379
# Epoch 172/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9208 - val_accuracy: 0.5100 - val_loss: 1.0373
# Epoch 173/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5859 - loss: 0.9172 - val_accuracy: 0.5099 - val_loss: 1.0365
# Epoch 174/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5859 - loss: 0.9137 - val_accuracy: 0.5100 - val_loss: 1.0359
# Epoch 175/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9104 - val_accuracy: 0.5100 - val_loss: 1.0353
# Epoch 176/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9071 - val_accuracy: 0.5100 - val_loss: 1.0347
# Epoch 177/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9040 - val_accuracy: 0.5100 - val_loss: 1.0342
# Epoch 178/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5859 - loss: 0.9008 - val_accuracy: 0.5101 - val_loss: 1.0337
# Epoch 179/1000
# 1/1 - 4s - 4s/step - accuracy: 0.5859 - loss: 0.8977 - val_accuracy: 0.5100 - val_loss: 1.0331
# Epoch 180/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5859 - loss: 0.8946 - val_accuracy: 0.5100 - val_loss: 1.0326
# Epoch 181/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 0.8916 - val_accuracy: 0.5100 - val_loss: 1.0319
# Epoch 182/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8886 - val_accuracy: 0.5101 - val_loss: 1.0310
# Epoch 183/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8857 - val_accuracy: 0.5102 - val_loss: 1.0301
# Epoch 184/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8829 - val_accuracy: 0.5104 - val_loss: 1.0291
# Epoch 185/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8800 - val_accuracy: 0.5106 - val_loss: 1.0281
# Epoch 186/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8772 - val_accuracy: 0.5108 - val_loss: 1.0271
# Epoch 187/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8744 - val_accuracy: 0.5111 - val_loss: 1.0261
# Epoch 188/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8718 - val_accuracy: 0.5113 - val_loss: 1.0252
# Epoch 189/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8692 - val_accuracy: 0.5116 - val_loss: 1.0244
# Epoch 190/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8666 - val_accuracy: 0.5119 - val_loss: 1.0237
# Epoch 191/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8642 - val_accuracy: 0.5123 - val_loss: 1.0231
# Epoch 192/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 0.8618 - val_accuracy: 0.5126 - val_loss: 1.0226
# Epoch 193/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8594 - val_accuracy: 0.5130 - val_loss: 1.0221
# Epoch 194/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 0.8571 - val_accuracy: 0.5136 - val_loss: 1.0217
# Epoch 195/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8548 - val_accuracy: 0.5140 - val_loss: 1.0211
# Epoch 196/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8525 - val_accuracy: 0.5145 - val_loss: 1.0205
# Epoch 197/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8503 - val_accuracy: 0.5152 - val_loss: 1.0199
# Epoch 198/1000
# 1/1 - 8s - 8s/step - accuracy: 0.5938 - loss: 0.8480 - val_accuracy: 0.5158 - val_loss: 1.0191
# Epoch 199/1000
# 1/1 - 6s - 6s/step - accuracy: 0.5938 - loss: 0.8458 - val_accuracy: 0.5163 - val_loss: 1.0183
# Epoch 200/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 0.8436 - val_accuracy: 0.5169 - val_loss: 1.0175
# Epoch 201/1000
# 1/1 - 8s - 8s/step - accuracy: 0.5938 - loss: 0.8415 - val_accuracy: 0.5174 - val_loss: 1.0166
# Epoch 202/1000
# 1/1 - 8s - 8s/step - accuracy: 0.5938 - loss: 0.8394 - val_accuracy: 0.5180 - val_loss: 1.0158
# Epoch 203/1000
# 1/1 - 3s - 3s/step - accuracy: 0.5938 - loss: 0.8372 - val_accuracy: 0.5186 - val_loss: 1.0151
# Epoch 204/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8351 - val_accuracy: 0.5192 - val_loss: 1.0146
# Epoch 205/1000
# 1/1 - 5s - 5s/step - accuracy: 0.5938 - loss: 0.8330 - val_accuracy: 0.5199 - val_loss: 1.0141
# Epoch 206/1000
# 1/1 - 8s - 8s/step - accuracy: 0.6016 - loss: 0.8310 - val_accuracy: 0.5207 - val_loss: 1.0137
# Epoch 207/1000
# 1/1 - 3s - 3s/step - accuracy: 0.
1000
# 1/1 - 3s - 3s/step - accuracy: 0.7188 - loss: 0.6952 - val_accuracy: 0.5612 - val_loss: 1.0045
# Epoch 268/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7188 - loss: 0.6926 - val_accuracy: 0.5623 - val_loss: 1.0041
# Epoch 269/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7266 - loss: 0.6900 - val_accuracy: 0.5638 - val_loss: 1.0035
# Epoch 270/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7344 - loss: 0.6874 - val_accuracy: 0.5650 - val_loss: 1.0032
# Epoch 271/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6848 - val_accuracy: 0.5664 - val_loss: 1.0033
# Epoch 272/1000
# 1/1 - 2s - 2s/step - accuracy: 0.7500 - loss: 0.6821 - val_accuracy: 0.5674 - val_loss: 1.0034
# Epoch 273/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7500 - loss: 0.6794 - val_accuracy: 0.5681 - val_loss: 1.0038
# Epoch 274/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7500 - loss: 0.6767 - val_accuracy: 0.5686 - val_loss: 1.0046
# Epoch 275/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7500 - loss: 0.6740 - val_accuracy: 0.5693 - val_loss: 1.0056
# Epoch 276/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7500 - loss: 0.6712 - val_accuracy: 0.5703 - val_loss: 1.0062
# Epoch 277/1000
# 1/1 - 2s - 2s/step - accuracy: 0.7578 - loss: 0.6684 - val_accuracy: 0.5716 - val_loss: 1.0063
# Epoch 278/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.6655 - val_accuracy: 0.5725 - val_loss: 1.0065
# Epoch 279/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.6625 - val_accuracy: 0.5733 - val_loss: 1.0071
# Epoch 280/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6595 - val_accuracy: 0.5738 - val_loss: 1.0082
# Epoch 281/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7500 - loss: 0.6565 - val_accuracy: 0.5741 - val_loss: 1.0093
# Epoch 282/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7500 - loss: 0.6534 - val_accuracy: 0.5740 - val_loss: 1.0102
# Epoch 283/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7500 - loss: 0.6504 - val_accuracy: 0.5742 - val_loss: 1.0109
# Epoch 284/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7500 - loss: 0.6474 - val_accuracy: 0.5747 - val_loss: 1.0109
# Epoch 285/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.6444 - val_accuracy: 0.5751 - val_loss: 1.0108
# Epoch 286/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6413 - val_accuracy: 0.5749 - val_loss: 1.0117
# Epoch 287/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6381 - val_accuracy: 0.5747 - val_loss: 1.0126
# Epoch 288/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6350 - val_accuracy: 0.5749 - val_loss: 1.0130
# Epoch 289/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6319 - val_accuracy: 0.5755 - val_loss: 1.0133
# Epoch 290/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6288 - val_accuracy: 0.5760 - val_loss: 1.0143
# Epoch 291/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.6257 - val_accuracy: 0.5758 - val_loss: 1.0157
# Epoch 292/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6224 - val_accuracy: 0.5755 - val_loss: 1.0175
# Epoch 293/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6192 - val_accuracy: 0.5763 - val_loss: 1.0171
# Epoch 294/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7500 - loss: 0.6159 - val_accuracy: 0.5766 - val_loss: 1.0175
# Epoch 295/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6127 - val_accuracy: 0.5760 - val_loss: 1.0200
# Epoch 296/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.6096 - val_accuracy: 0.5761 - val_loss: 1.0208
# Epoch 297/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.6065 - val_accuracy: 0.5760 - val_loss: 1.0212
# Epoch 298/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7578 - loss: 0.6034 - val_accuracy: 0.5753 - val_loss: 1.0229
# Epoch 299/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.6003 - val_accuracy: 0.5751 - val_loss: 1.0252
# Epoch 300/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5972 - val_accuracy: 0.5754 - val_loss: 1.0266
# Epoch 301/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5940 - val_accuracy: 0.5757 - val_loss: 1.0276
# Epoch 302/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5910 - val_accuracy: 0.5758 - val_loss: 1.0299
# Epoch 303/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5881 - val_accuracy: 0.5763 - val_loss: 1.0319
# Epoch 304/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5850 - val_accuracy: 0.5767 - val_loss: 1.0340
# Epoch 305/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5822 - val_accuracy: 0.5773 - val_loss: 1.0356
# Epoch 306/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5793 - val_accuracy: 0.5781 - val_loss: 1.0355
# Epoch 307/1000
# 1/1 - 2s - 2s/step - accuracy: 0.7578 - loss: 0.5763 - val_accuracy: 0.5788 - val_loss: 1.0374
# Epoch 308/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7656 - loss: 0.5734 - val_accuracy: 0.5793 - val_loss: 1.0399
# Epoch 309/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7578 - loss: 0.5704 - val_accuracy: 0.5796 - val_loss: 1.0421
# Epoch 310/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.5676 - val_accuracy: 0.5800 - val_loss: 1.0434
# Epoch 311/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7578 - loss: 0.5647 - val_accuracy: 0.5801 - val_loss: 1.0468
# Epoch 312/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7578 - loss: 0.5617 - val_accuracy: 0.5803 - val_loss: 1.0501
# Epoch 313/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7656 - loss: 0.5587 - val_accuracy: 0.5804 - val_loss: 1.0522
# Epoch 314/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7734 - loss: 0.5558 - val_accuracy: 0.5808 - val_loss: 1.0559
# Epoch 315/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7734 - loss: 0.5528 - val_accuracy: 0.5814 - val_loss: 1.0589
# Epoch 316/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7891 - loss: 0.5498 - val_accuracy: 0.5817 - val_loss: 1.0596
# Epoch 317/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7891 - loss: 0.5467 - val_accuracy: 0.5825 - val_loss: 1.0612
# Epoch 318/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7891 - loss: 0.5437 - val_accuracy: 0.5829 - val_loss: 1.0662
# Epoch 319/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7891 - loss: 0.5406 - val_accuracy: 0.5835 - val_loss: 1.0696
# Epoch 320/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7891 - loss: 0.5376 - val_accuracy: 0.5839 - val_loss: 1.0694
# Epoch 321/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7891 - loss: 0.5345 - val_accuracy: 0.5844 - val_loss: 1.0711
# Epoch 322/1000
# 1/1 - 4s - 4s/step - accuracy: 0.7891 - loss: 0.5314 - val_accuracy: 0.5851 - val_loss: 1.0758
# Epoch 323/1000
# 1/1 - 2s - 2s/step - accuracy: 0.7969 - loss: 0.5284 - val_accuracy: 0.5853 - val_loss: 1.0772
# Epoch 324/1000
# 1/1 - 3s - 3s/step - accuracy: 0.7969 - loss: 0.5254 - val_accuracy: 0.5849 - val_loss: 1.0776
# Epoch 325/1000
# 1/1 - 5s - 5s/step - accuracy: 0.7969 - loss: 0.5225 - val_accuracy: 0.5851 - val_loss: 1.0840
# Epoch 326/1000
# 1/1 - 5s - 5s/step - accuracy: 0.8047 - loss: 0.5193 - val_accuracy: 0.5848 - val_loss: 1.0887
# Epoch 327/1000
# 1/1 - 5s - 5s/step - accuracy: 0.8047 - loss: 0.5164 - val_accuracy: 0.5843 - val_loss: 1.0869
# Epoch 328/1000
# 1/1 - 5s - 5s/step - accuracy: 0.8047 - loss: 0.5134 - val_accuracy: 0.5842 - val_loss: 1.0934
# Epoch 329/1000
# 1/1 - 3s - 3s/step - accuracy: 0.8047 - loss: 0.5104 - val_accuracy: 0.5842 - val_loss: 1.1006
# Epoch 330/1000
# 1/1 - 5s - 5s/step - accuracy: 0.8047 - loss: 0.5079 - val_accuracy: 0.5847 - val_loss: 1.0978
# Epoch 331/1000
# 1/1 - 5s - 5s/step - accuracy: 0.8047 - loss: 0.5049 - val_accuracy: 0.5852 - val_loss: 1.0993
# Epoch 332/1000
# 1/1 - 4s - 4s/step - accuracy: 0.8125 - loss: 0.5022 - val_accuracy: 0.5850 - val_loss: 1.1097
# Epoch 333/1000
# 1/1 - 3s - 3s/step - accuracy: 0.8047 - loss: 0.4995 - val_accuracy: 0.5851 - val_loss: 1.1123
# Epoch 334/1000
# 1/1 - 5s - 5s/step - accuracy: 0.
1000
# 1/1 - 2s - 2s/step - accuracy: 0.9688 - loss: 0.0912 - val_accuracy: 0.5503 - val_loss: 4.8044
# Epoch 895/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0905 - val_accuracy: 0.5498 - val_loss: 4.8070
# Epoch 896/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0901 - val_accuracy: 0.5495 - val_loss: 4.8053
# Epoch 897/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0902 - val_accuracy: 0.5509 - val_loss: 4.8416
# Epoch 898/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9844 - loss: 0.0906 - val_accuracy: 0.5491 - val_loss: 4.8159
# Epoch 899/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0904 - val_accuracy: 0.5507 - val_loss: 4.8548
# Epoch 900/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9844 - loss: 0.0899 - val_accuracy: 0.5494 - val_loss: 4.8386
# Epoch 901/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0893 - val_accuracy: 0.5500 - val_loss: 4.8595
# Epoch 902/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0889 - val_accuracy: 0.5502 - val_loss: 4.8718
# Epoch 903/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0887 - val_accuracy: 0.5494 - val_loss: 4.8652
# Epoch 904/1000
# 1/1 - 2s - 2s/step - accuracy: 0.9688 - loss: 0.0888 - val_accuracy: 0.5504 - val_loss: 4.8998
# Epoch 905/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9844 - loss: 0.0888 - val_accuracy: 0.5488 - val_loss: 4.8809
# Epoch 906/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0885 - val_accuracy: 0.5500 - val_loss: 4.9112
# Epoch 907/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0880 - val_accuracy: 0.5491 - val_loss: 4.9033
# Epoch 908/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0875 - val_accuracy: 0.5494 - val_loss: 4.9190
# Epoch 909/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0871 - val_accuracy: 0.5496 - val_loss: 4.9299
# Epoch 910/1000
# 1/1 - 2s - 2s/step - accuracy: 0.9688 - loss: 0.0868 - val_accuracy: 0.5491 - val_loss: 4.9316
# Epoch 911/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0865 - val_accuracy: 0.5492 - val_loss: 4.9497
# Epoch 912/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9688 - loss: 0.0863 - val_accuracy: 0.5485 - val_loss: 4.9454
# Epoch 913/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0860 - val_accuracy: 0.5490 - val_loss: 4.9649
# Epoch 914/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0857 - val_accuracy: 0.5488 - val_loss: 4.9625
# Epoch 915/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0854 - val_accuracy: 0.5493 - val_loss: 4.9771
# Epoch 916/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0852 - val_accuracy: 0.5491 - val_loss: 4.9767
# Epoch 917/1000
# 1/1 - 2s - 2s/step - accuracy: 0.9688 - loss: 0.0848 - val_accuracy: 0.5492 - val_loss: 4.9839
# Epoch 918/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0845 - val_accuracy: 0.5494 - val_loss: 4.9910
# Epoch 919/1000
# 1/1 - 2s - 2s/step - accuracy: 0.9688 - loss: 0.0843 - val_accuracy: 0.5493 - val_loss: 4.9914
# Epoch 920/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0840 - val_accuracy: 0.5498 - val_loss: 5.0069
# Epoch 921/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0838 - val_accuracy: 0.5496 - val_loss: 5.0019
# Epoch 922/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0835 - val_accuracy: 0.5499 - val_loss: 5.0163
# Epoch 923/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0832 - val_accuracy: 0.5497 - val_loss: 5.0149
# Epoch 924/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9688 - loss: 0.0829 - val_accuracy: 0.5500 - val_loss: 5.0259
# Epoch 925/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0827 - val_accuracy: 0.5503 - val_loss: 5.0305
# Epoch 926/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0824 - val_accuracy: 0.5503 - val_loss: 5.0377
# Epoch 927/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0822 - val_accuracy: 0.5503 - val_loss: 5.0453
# Epoch 928/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0818 - val_accuracy: 0.5502 - val_loss: 5.0510
# Epoch 929/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0814 - val_accuracy: 0.5506 - val_loss: 5.0650
# Epoch 930/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9688 - loss: 0.0810 - val_accuracy: 0.5507 - val_loss: 5.0632
# Epoch 931/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0807 - val_accuracy: 0.5514 - val_loss: 5.0882
# Epoch 932/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9844 - loss: 0.0804 - val_accuracy: 0.5507 - val_loss: 5.0817
# Epoch 933/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0799 - val_accuracy: 0.5511 - val_loss: 5.1098
# Epoch 934/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9844 - loss: 0.0795 - val_accuracy: 0.5502 - val_loss: 5.1032
# Epoch 935/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9688 - loss: 0.0787 - val_accuracy: 0.5507 - val_loss: 5.1359
# Epoch 936/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9844 - loss: 0.0779 - val_accuracy: 0.5496 - val_loss: 5.1222
# Epoch 937/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0772 - val_accuracy: 0.5501 - val_loss: 5.1583
# Epoch 938/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0767 - val_accuracy: 0.5484 - val_loss: 5.1360
# Epoch 939/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0763 - val_accuracy: 0.5493 - val_loss: 5.1783
# Epoch 940/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9922 - loss: 0.0759 - val_accuracy: 0.5479 - val_loss: 5.1446
# Epoch 941/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0753 - val_accuracy: 0.5495 - val_loss: 5.1943
# Epoch 942/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0749 - val_accuracy: 0.5481 - val_loss: 5.1565
# Epoch 943/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0743 - val_accuracy: 0.5498 - val_loss: 5.2021
# Epoch 944/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0736 - val_accuracy: 0.5487 - val_loss: 5.1761
# Epoch 945/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0730 - val_accuracy: 0.5496 - val_loss: 5.2083
# Epoch 946/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0725 - val_accuracy: 0.5491 - val_loss: 5.2007
# Epoch 947/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9766 - loss: 0.0722 - val_accuracy: 0.5494 - val_loss: 5.2088
# Epoch 948/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0717 - val_accuracy: 0.5493 - val_loss: 5.2176
# Epoch 949/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0715 - val_accuracy: 0.5484 - val_loss: 5.2111
# Epoch 950/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0712 - val_accuracy: 0.5487 - val_loss: 5.2396
# Epoch 951/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0712 - val_accuracy: 0.5472 - val_loss: 5.2248
# Epoch 952/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0711 - val_accuracy: 0.5481 - val_loss: 5.2635
# Epoch 953/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0710 - val_accuracy: 0.5462 - val_loss: 5.2401
# Epoch 954/1000
# 1/1 - 2s - 2s/step - accuracy: 0.9766 - loss: 0.0712 - val_accuracy: 0.5476 - val_loss: 5.2878
# Epoch 955/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0712 - val_accuracy: 0.5454 - val_loss: 5.2517
# Epoch 956/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0711 - val_accuracy: 0.5477 - val_loss: 5.3074
# Epoch 957/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9922 - loss: 0.0711 - val_accuracy: 0.5463 - val_loss: 5.2649
# Epoch 958/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0709 - val_accuracy: 0.5488 - val_loss: 5.3193
# Epoch 959/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0703 - val_accuracy: 0.5471 - val_loss: 5.2864
# Epoch 960/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0696 - val_accuracy: 0.5481 - val_loss: 5.3251
# Epoch 961/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0687 - val_accuracy: 0.5469 - val_loss: 5.3172
# Epoch 962/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0681 - val_accuracy: 0.5473 - val_loss: 5.3334
# Epoch 963/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0677 - val_accuracy: 0.5476 - val_loss: 5.3517
# Epoch 964/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0675 - val_accuracy: 0.5474 - val_loss: 5.3461
# Epoch 965/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9766 - loss: 0.0675 - val_accuracy: 0.5481 - val_loss: 5.3801
# Epoch 966/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0675 - val_accuracy: 0.5468 - val_loss: 5.3588
# Epoch 967/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0675 - val_accuracy: 0.5475 - val_loss: 5.4046
# Epoch 968/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0675 - val_accuracy: 0.5462 - val_loss: 5.3759
# Epoch 969/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0675 - val_accuracy: 0.5473 - val_loss: 5.4287
# Epoch 970/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0671 - val_accuracy: 0.5464 - val_loss: 5.4001
# Epoch 971/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9766 - loss: 0.0668 - val_accuracy: 0.5473 - val_loss: 5.4459
# Epoch 972/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0662 - val_accuracy: 0.5465 - val_loss: 5.4257
# Epoch 973/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0657 - val_accuracy: 0.5466 - val_loss: 5.4562
# Epoch 974/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9922 - loss: 0.0651 - val_accuracy: 0.5464 - val_loss: 5.4532
# Epoch 975/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0647 - val_accuracy: 0.5463 - val_loss: 5.4678
# Epoch 976/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9844 - loss: 0.0644 - val_accuracy: 0.5463 - val_loss: 5.4853
# Epoch 977/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0643 - val_accuracy: 0.5460 - val_loss: 5.4825
# Epoch 978/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0643 - val_accuracy: 0.5463 - val_loss: 5.5175
# Epoch 979/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0644 - val_accuracy: 0.5451 - val_loss: 5.4969
# Epoch 980/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0645 - val_accuracy: 0.5460 - val_loss: 5.5465
# Epoch 981/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0647 - val_accuracy: 0.5444 - val_loss: 5.5111
# Epoch 982/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0650 - val_accuracy: 0.5461 - val_loss: 5.5743
# Epoch 983/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0651 - val_accuracy: 0.5441 - val_loss: 5.5302
# Epoch 984/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9766 - loss: 0.0649 - val_accuracy: 0.5458 - val_loss: 5.5945
# Epoch 985/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0645 - val_accuracy: 0.5442 - val_loss: 5.5585
# Epoch 986/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0635 - val_accuracy: 0.5450 - val_loss: 5.6005
# Epoch 987/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0625 - val_accuracy: 0.5445 - val_loss: 5.5953
# Epoch 988/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9844 - loss: 0.0620 - val_accuracy: 0.5443 - val_loss: 5.6046
# Epoch 989/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0618 - val_accuracy: 0.5446 - val_loss: 5.6325
# Epoch 990/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0618 - val_accuracy: 0.5437 - val_loss: 5.6160
# Epoch 991/1000
# 1/1 - 2s - 2s/step - accuracy: 0.9766 - loss: 0.0621 - val_accuracy: 0.5449 - val_loss: 5.6633
# Epoch 992/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0622 - val_accuracy: 0.5437 - val_loss: 5.6349
# Epoch 993/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0620 - val_accuracy: 0.5449 - val_loss: 5.6815
# Epoch 994/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9922 - loss: 0.0615 - val_accuracy: 0.5437 - val_loss: 5.6610
# Epoch 995/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9766 - loss: 0.0610 - val_accuracy: 0.5441 - val_loss: 5.6918
# Epoch 996/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0605 - val_accuracy: 0.5440 - val_loss: 5.6950
# Epoch 997/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9844 - loss: 0.0601 - val_accuracy: 0.5438 - val_loss: 5.6993
# Epoch 998/1000
# 1/1 - 5s - 5s/step - accuracy: 0.9766 - loss: 0.0601 - val_accuracy: 0.5441 - val_loss: 5.7235
# Epoch 999/1000
# 1/1 - 3s - 3s/step - accuracy: 0.9922 - loss: 0.0603 - val_accuracy: 0.5429 - val_loss: 5.6975
# Epoch 1000/1000
# 1/1 - 4s - 4s/step - accuracy: 0.9766 - loss: 0.0606 - val_accuracy: 0.5433 - val_loss: 5.7411

# %%
preds = model(X_val)
crt = 0

for pd, label in zip(preds, y_val):
    if np.argmax(pd) == np.argmax(label):
        crt += 1

print("correct num:", crt)
print("validation accuracy", crt/len(y_val))


print("number correct:", correct)
print("validation accuracy:", correct/len(y_val))
# Out:
# number correct: 0
# validation accuracy: 0.0

# %% [markdown]
# # *Conclusion*
#
# Number of Parameters: 777
#
# Final Training Loss: 0.0606
#
# Final Validation Loss: 5.7411
